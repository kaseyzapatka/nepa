# %%
#!pip install scattertext wordcloud spacy

#import sys
#print(sys.executable)
# Out:
# /opt/anaconda3/envs/textanalysis/bin/python

# %%
import os
from pathlib import Path

import spacy
import scattertext as st
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# Get the directory where this notebook is located
#notebook_dir = Path.cwd()  # or os.getcwd()
#print(f"Current directory: {notebook_dir}")

# Or force it to be the notebook's directory
# notebook_dir = Path(__file__).parent  # doesn't work in notebooks

# %%
#%pip install pyarrow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.0/36.0 MB 43.7 MB/s  0:00:00 eta 0:00:010:01:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Verify the current working directory
notebook_dir = Path.cwd()  # or os.getcwd()
print(f"Current directory: {notebook_dir}")
# Out:
# Current directory: /Users/Dora/git/consulting/nepa/code

# %%
import pandas as pd

# Read entire file
projects = pd.read_parquet('../data/processed/ce/projects.parquet')
process = pd.read_parquet("../data/processed/ce/processes.parquet")
documents = pd.read_parquet('../data/processed/ce/documents.parquet')
pages = pd.read_parquet('../data/processed/ce/pages.parquet')

# %%
projects.head()
# Out:
#                                           project_id  \
# 0  {'value': '840aac91-a94d-0bb3-5338-73bb83674ae5'}
# 1  {'value': '6d2848e8-5c52-555b-e549-fa3f275089a4'}
# 2  {'value': '8da280bf-8917-d807-ecc7-3b81652b037c'}
# 3  {'value': '54391a5b-0a7b-7713-ca52-4d5391902f19'}
# 4  {'value': 'fc8d1695-09d2-4c70-ef06-70dd3efc0cfc'}
#
#                                        project_title  \
# 0  Nebel Coulee Allotment Grazing Preference Tran...
# 1  Solaris Midstream, LLC Right-of-Way for Buried...
# 2  EOG Resources Incorporated Ruby 1819-16H Well Pad
# 3                          Special Recreation Permit
# 4  Jackson Mountain Allotment # 46330 Grazing Pre...
#
#                                       project_sector  \
# 0  [Agriculture and Natural Resource Management, ...
# 1  [Land Development and Urban Planning, Energy P...
# 2  [Land Development and Urban Planning, Energy P...
# 3              [Land Development and Urban Planning]
# ...

# %%
#type(projects.project_sector)

#projects.project_sector.tolist()
#projects.project_location.tolist()
projects.project_location.head(50)
# Out:
# 0     [Nebel Coulee #09665, T. 16 N., R. 9 E., Sec. ...
# 1     [T. 25 S., R. 35 E., NMPM, sec. 20: E2NW¼, New...
# 2     [Sixth Principal Meridian, Wyoming\nT. 40 N., ...
# 3     [The area of the proposed action includes all ...
# 4     [T6S, R22E, Sections: 8,16-22, 28-30\nT6S, R21...
# 5     [Potash Rd and State Route 279\nSalt Lake Meri...
# 6                                   [Armargosa, Nevada]
# 7     [Sweetwater County, Wyoming, 6th Principal Mer...
# 8     [Adobe Lake Allotment - Bishop Resource Manage...
# 9     [Bill Williams Mountains in Mohave County, AZ,...
# 10    [Sec. 15, T30N, R108W, 6th Principal Meridian,...
# 11            [3100 H Street, Baker City, Oregon 97814]
# 12          [NE of Montrose, Montrose County, Colorado]
# 13    [Grand County, Utah\nSeven Mile Rim and Mill C...
# 14    [MDM, T. 23 S., R. 63 E., sec. 11, lot 7, Nevada]
# 15    [Fisher Towers\nSalt Lake Meridian, Utah\nT. 2...
# 16    [Principal Meridian, Carbon County, Montana\n\...
# ...

# %%
process.head()
# Out:
#                                           project_id  \
# 0  {'value': '840aac91-a94d-0bb3-5338-73bb83674ae5'}
# 1  {'value': '6d2848e8-5c52-555b-e549-fa3f275089a4'}
# 2  {'value': '8da280bf-8917-d807-ecc7-3b81652b037c'}
# 3  {'value': '54391a5b-0a7b-7713-ca52-4d5391902f19'}
# 4  {'value': 'fc8d1695-09d2-4c70-ef06-70dd3efc0cfc'}
#
#                                     process_family           process_type  \
# 0  National Environmental Policy Act (NEPA) Review  Categorical Exclusion
# 1  National Environmental Policy Act (NEPA) Review  Categorical Exclusion
# 2  National Environmental Policy Act (NEPA) Review  Categorical Exclusion
# 3  National Environmental Policy Act (NEPA) Review  Categorical Exclusion
# 4  National Environmental Policy Act (NEPA) Review  Categorical Exclusion
#
#                                          lead_agency
# 0  [Department of the Interior - Bureau of Land M...
# 1  [Department of the Interior - Bureau of Land M...
# ...

# %%
process.process_type.unique()
# Out:
# array(['Categorical Exclusion'], dtype=object)

# %%
documents.head()
# Out:
#                                           project_id  \
# 0  {'value': '840aac91-a94d-0bb3-5338-73bb83674ae5'}
# 1  {'value': '6d2848e8-5c52-555b-e549-fa3f275089a4'}
# 2  {'value': '6d2848e8-5c52-555b-e549-fa3f275089a4'}
# 3  {'value': '8da280bf-8917-d807-ecc7-3b81652b037c'}
# 4  {'value': '54391a5b-0a7b-7713-ca52-4d5391902f19'}
#
#                             document_id document_type  \
# 0  36009af6-4709-ea8e-3c66-137c9d9a2089            CE
# 1  f8784150-e64d-c56e-3acc-b54aee648f43            CE
# 2  ab833fc6-271a-1eaf-edc0-19b84d4a3132         OTHER
# 3  9156eace-d599-5bf1-cff2-f0ff03b7cf6d           ROD
# 4  a3fddde4-b916-9ee8-5be4-a9a2f551eb15            CE
#
#                                       document_title  \
# 0          CATEGORICAL EXCLUSION REVIEW AND APPROVAL
# 1  NEPA COMPLIANCE RECORD FOR CATEGORICAL EXCLUSI...
# 2
# 3  Categorical Exclusion and Decision Record for ...
# 4  Categorical Exclusion Not Established By Statu...
#
# ...

# %%
pages.head()
# Out:
#                             document_id page_number  \
# 0  36009af6-4709-ea8e-3c66-137c9d9a2089         1-6
# 1  f8784150-e64d-c56e-3acc-b54aee648f43         1-3
# 2  ab833fc6-271a-1eaf-edc0-19b84d4a3132         1-3
# 3  9156eace-d599-5bf1-cff2-f0ff03b7cf6d         1-7
# 4  a3fddde4-b916-9ee8-5be4-a9a2f551eb15         1-8
#
#                                            page_text
# 0  U.S. Department of the Interior\nBureau of Lan...
# 1  NEPA COMPLIANCE RECORD FOR CATEGORICAL EXCLUSI...
# 2  NEPA COMPLIANCE RECORD FOR CATEGORICAL EXCLUSI...
# 3  NATIONAL SYSTEM OF PUBLIC LANDS\nU.S. DEPARTME...
# 4  United States Department of the Interior\nBure...

# %%
print(pages.page_text[1])

# %%
# Loop through first 15 rows
for i in range(5):
    print(f"--- START PAGE {i} ---")
    print(pages.page_text[i])
    print(f"--- END PAGE {i} ---")
    print()  # Empty line for separation
# Out:
# --- START PAGE 0 ---
# U.S. Department of the Interior
# Bureau of Land Management
#
# BLM
#
# CATEGORICAL EXCLUSION REVIEW AND APPROVAL
# DOI-BLM-MT-L060-2018-0001-CX
# Project Title: Nebel Coulee Allotment Grazing Preference Transfer.
#
# Location: Nebel Coulee #09665, T. 16 N., R. 9 E., Sec. 30: Lots 5-8, 30-6-19; Sec. 3
# Lots 1-14, 31 – 16 – 9; Judith Basin County, Montana.
#
# Otter
# Irene Peak
# 36
# Creek
# 09665
# Coulee
#
# Applicant/Address: Joseph C. Bodner
# 3260 Otter Creek Road
# Raynesford, Montana 59469
#
# Project Contact:
# Name:
# Title:
# Office:
# Telephone No.:
# Linda Birdwell
# Legal Instruments Examiner
# Lewistown Field Office
# (406) 538-1947
#
# Lewistown Field Office
# 920 NE Main Street
# Lewistown, Montana 59457
# Phone: 406-538-1900
#
# NATIONAL SYSTEM OF PUBLIC LANDS
# U.S. DEPARTMENT OF THE INTERIOR
# BUREAU OF LAND MANAGEMENT
#
# CATEGORICAL EXCLUSION REVIEW AND APPROVAL
# A. Background
#
# ...

# %%
pages
# Out:
#                                 document_id page_number  \
# 0      36009af6-4709-ea8e-3c66-137c9d9a2089         1-6
# 1      f8784150-e64d-c56e-3acc-b54aee648f43         1-3
# 2      ab833fc6-271a-1eaf-edc0-19b84d4a3132         1-3
# 3      9156eace-d599-5bf1-cff2-f0ff03b7cf6d         1-7
# 4      a3fddde4-b916-9ee8-5be4-a9a2f551eb15         1-8
# ...                                     ...         ...
# 73539  57b5b183-fe29-62af-9402-e8360cb38384         1-4
# 73540  853b96cb-56c6-3b91-7320-224dcc4e45cf         1-3
# 73541  835e6899-5d46-2ab6-d2bf-e29bafef2ab6         1-7
# 73542  e1d25b63-3d9f-fbd6-416c-96edbc1a31a8        1-25
# 73543  5d45704e-adcb-6fd3-5875-97c949c44aa9         1-5
#
#                                                page_text
# 0      U.S. Department of the Interior\nBureau of Lan...
# 1      NEPA COMPLIANCE RECORD FOR CATEGORICAL EXCLUSI...
# 2      NEPA COMPLIANCE RECORD FOR CATEGORICAL EXCLUSI...
# 3      NATIONAL SYSTEM OF PUBLIC LANDS\nU.S. DEPARTME...
# ...

# %%
docs_pages = documents.merge(pages, on='document_id', how='inner')
docs_pages.head()
# Out:
#                                           project_id  \
# 0  {'value': '840aac91-a94d-0bb3-5338-73bb83674ae5'}
# 1  {'value': '6d2848e8-5c52-555b-e549-fa3f275089a4'}
# 2  {'value': '6d2848e8-5c52-555b-e549-fa3f275089a4'}
# 3  {'value': '8da280bf-8917-d807-ecc7-3b81652b037c'}
# 4  {'value': '54391a5b-0a7b-7713-ca52-4d5391902f19'}
#
#                             document_id document_type  \
# 0  36009af6-4709-ea8e-3c66-137c9d9a2089            CE
# 1  f8784150-e64d-c56e-3acc-b54aee648f43            CE
# 2  ab833fc6-271a-1eaf-edc0-19b84d4a3132         OTHER
# 3  9156eace-d599-5bf1-cff2-f0ff03b7cf6d           ROD
# 4  a3fddde4-b916-9ee8-5be4-a9a2f551eb15            CE
#
#                                       document_title  \
# 0          CATEGORICAL EXCLUSION REVIEW AND APPROVAL
# 1  NEPA COMPLIANCE RECORD FOR CATEGORICAL EXCLUSI...
# 2
# 3  Categorical Exclusion and Decision Record for ...
# 4  Categorical Exclusion Not Established By Statu...
#
# ...

# %%
docs_pages.document_type.unique()
# Out:
# array(['CE', 'OTHER', 'ROD', 'FONSI', 'EA', '', 'DEA'], dtype=object)

# %%
test = docs_pages[0:100]
test
#test.shape
# Out:
#                                            project_id  \
# 0   {'value': '840aac91-a94d-0bb3-5338-73bb83674ae5'}
# 1   {'value': '6d2848e8-5c52-555b-e549-fa3f275089a4'}
# 2   {'value': '6d2848e8-5c52-555b-e549-fa3f275089a4'}
# 3   {'value': '8da280bf-8917-d807-ecc7-3b81652b037c'}
# 4   {'value': '54391a5b-0a7b-7713-ca52-4d5391902f19'}
# ..                                                ...
# 95  {'value': '014dc6a0-7290-9f70-9819-75d8cde90236'}
# 96  {'value': '014dc6a0-7290-9f70-9819-75d8cde90236'}
# 97  {'value': '014dc6a0-7290-9f70-9819-75d8cde90236'}
# 98  {'value': '0e121bcd-45c1-9a84-7ef0-37276910ecfe'}
# 99  {'value': '0e121bcd-45c1-9a84-7ef0-37276910ecfe'}
#
#                              document_id document_type  \
# 0   36009af6-4709-ea8e-3c66-137c9d9a2089            CE
# 1   f8784150-e64d-c56e-3acc-b54aee648f43            CE
# 2   ab833fc6-271a-1eaf-edc0-19b84d4a3132         OTHER
# 3   9156eace-d599-5bf1-cff2-f0ff03b7cf6d           ROD
# ...

# %%
import spacy

from scattertext import SampleCorpora, produce_scattertext_explorer
from scattertext import produce_scattertext_html
from scattertext.CorpusFromPandas import CorpusFromPandas

nlp = spacy.load('en_core_web_sm')
#convention_df = SampleCorpora.ConventionData2012.get_data()
short_docs = docs_pages[0:100]
corpus = CorpusFromPandas(short_docs,
                          category_col='document_type',
                          text_col='page_text',
                          nlp=nlp).build()


# create html document
html = st.produce_scattertext_explorer(corpus,
                                       category='CE',
                                       category_name='Categorical Exclusion',
                                       not_category_name='Other',
                                       width_in_pixels=1000,
                                       minimum_term_frequency=5,
                                       metadata=short_docs['document_id'])

open('../output/scattertext/ce.html', 'wb').write(html.encode('utf-8'))
print('Open ../output/scattertext/ce.html in web browser.')
# Out:
# Open ./simple.html in Chrome or Firefox.
